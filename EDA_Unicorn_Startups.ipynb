# %% [markdown]
# # Data Overview

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
exited_df_3 = pd.read_csv("Exited_Companies.csv", encoding='unicode_escape')

# %%
emerging_df_3 = pd.read_csv("Emerging_Companies.csv", encoding='unicode_escape')

# %%
existing_df_3 = pd.read_csv("Unicorn Companies (Latest).csv", encoding='unicode_escape')

# %% [markdown]
# # <center> EDA

# %% [markdown]
# ### Preliminary EDA:
#     1. Generate a report detailing the data types of each column in the dataset.
#     2. Compute and display basic statistical summaries.
#     3. Identify any missing values in the dataset.

# %% [markdown]
# #### Exited Unicorn Companies

# %%
exited_df_3.head(5)
# Out:
#              Organisation        Country  \
# 0            10X Genomics  United States
# 1                 17zuoye          China
# 2                 23andMe  United States
# 3  51 Credit Card Manager          China
# 4                9F Group          China
#
#                                             Industry  \
# 0  BioSoftware & Technology, Genetics, Health Car...
# 1  E-Learning, EdTech, Education, Internet, Langu...
# 2   BioSoftware & Technology, Genetics, Life Science
# 3  Credit Cards, Finance, Financial Services, Fin...
# 4                        Financial Services, FinTech
#
#                 Main Industry      Month  Year  Exit Reason Main Reason
# 0  Healthcare & BioTechnology  September  2019     Bankrupt    Bankrupt
# 1        Education and EdTech   December  2020     Bankrupt    Bankrupt
# 2  Healthcare & BioTechnology       June  2021  SPAC merger      Merger
# 3         Finance and FinTech       July  2018     Bankrupt    Bankrupt
# ...

# %%
# Display data types of each column
data_types_report = exited_df_3.dtypes

# Count the number of categorical and numerical columns
categorical_columns = exited_df_3.select_dtypes(include='object').columns
numerical_columns = exited_df_3.select_dtypes(exclude='object').columns

num_categorical_columns = len(categorical_columns)
num_numerical_columns = len(numerical_columns)

# Print the report
print("Data Types Report:")
print(data_types_report)
print("\nNumber of Categorical Columns:", num_categorical_columns)
print("Number of Numerical Columns:", num_numerical_columns)
# Out:
# Data Types Report:
# Organisation     object
# Country          object
# Industry         object
# Main Industry    object
# Month            object
# Year              int64
# Exit Reason      object
# Main Reason      object
# dtype: object
#
# Number of Categorical Columns: 7
# Number of Numerical Columns: 1

# %%
exited_df_3.describe()
# Out:
#               Year
# count   468.000000
# mean   2019.506410
# std       2.595904
# min    2006.000000
# 25%    2018.000000
# 50%    2020.000000
# 75%    2021.000000
# max    2023.000000

# %%
print(exited_df_3.isnull().sum())
# Out:
# Organisation     0
# Country          0
# Industry         0
# Main Industry    0
# Month            0
# Year             0
# Exit Reason      0
# Main Reason      0
# dtype: int64

# %% [markdown]
# #### Emerging Unicorn Companies

# %%
emerging_df_3.head(5)
# Out:
#     Company  Post Money Value  Total Equity Funding  \
# 0       C2x               500                    25
# 1      SEON               500                   108
# 2  Envisics               500                   150
# 3    Porter               500                   132
# 4      FINN               500                   144
#
#                         Lead Investors Include         Country      Continent
# 0          Galaxy Interactive, Agnitio Capital   United States  North America
# 1                                          IVP         Hungary         Europe
# 2                              M&G Investments  United Kingdom         Europe
# 3  Tiger Global Management, Vitruvian Partners           India           Asia
# 4                              Korelya Capital         Germany         Europe

# %%
# Display data types of each column
data_types_report = emerging_df_3.dtypes

# Count the number of categorical and numerical columns
categorical_columns = emerging_df_3.select_dtypes(include='object').columns
numerical_columns = emerging_df_3.select_dtypes(exclude='object').columns

num_categorical_columns = len(categorical_columns)
num_numerical_columns = len(numerical_columns)

# Print the report
print("Data Types Report:")
print(data_types_report)
print("\nNumber of Categorical Columns:", num_categorical_columns)
print("Number of Numerical Columns:", num_numerical_columns)
# Out:
# Data Types Report:
# Company                   object
# Post Money Value           int64
# Total Equity Funding       int64
# Lead Investors Include    object
# Country                   object
# Continent                 object
# dtype: object
#
# Number of Categorical Columns: 4
# Number of Numerical Columns: 2

# %%
emerging_df_3.describe()
# Out:
#        Post Money Value  Total Equity Funding
# count        380.000000            380.000000
# mean         679.610526            174.126316
# std          142.431045            113.012339
# min          500.000000              0.000000
# 25%          550.000000            108.000000
# 50%          673.500000            152.500000
# 75%          800.000000            214.250000
# max          986.000000            935.000000

# %%
print(emerging_df_3.isnull().sum())
# Out:
# Company                   0
# Post Money Value          0
# Total Equity Funding      0
# Lead Investors Include    0
# Country                   0
# Continent                 0
# dtype: int64

# %% [markdown]
# #### Existing Unicorn Companies

# %%
existing_df_3.head(5)
# Out:
#          Company  Post Money Value  Total Equity Funding  \
# 0          01.AI                 1                   0.0
# 1     1047 Games                 2                 117.0
# 2  1inch Limited                 2                 190.0
# 3          1KMXC                 1                  86.0
# 4       1Komma5°                 1                 490.0
#
#         Lead Investors Include        Country      Continent  Month  Year  \
# 0                   Kai-Fu Lee          China           Asia     10  2015
# 1  Lightspeed Venture Partners  United States  North America      9  2021
# 2                  Amber Group  United States  North America      5  2021
# 3                 Haoteng Asia          China           Asia      8  2021
# 4                         2150        Germany         Europe      6  2023
#
#                 Industry
# 0        Enterprise Tech
# 1  Media & Entertainment
# 2        Enterprise Tech
# 3            Industrials
# 4            Industrials

# %%
# Display data types of each column
data_types_report = existing_df_3.dtypes

# Count the number of categorical and numerical columns
categorical_columns = existing_df_3.select_dtypes(include='object').columns
numerical_columns = existing_df_3.select_dtypes(exclude='object').columns

num_categorical_columns = len(categorical_columns)
num_numerical_columns = len(numerical_columns)

# Print the report
print("Data Types Report:")
print(data_types_report)
print("\nNumber of Categorical Columns:", num_categorical_columns)
print("Number of Numerical Columns:", num_numerical_columns)
# Out:
# Data Types Report:
# Company                    object
# Post Money Value            int64
# Total Equity Funding      float64
# Lead Investors Include     object
# Country                    object
# Continent                  object
# Month                       int64
# Year                        int64
# Industry                   object
# dtype: object
#
# Number of Categorical Columns: 5
# Number of Numerical Columns: 4

# %%
existing_df_3.describe()
# Out:
#        Post Money Value  Total Equity Funding        Month         Year
# count       1256.000000           1256.000000  1256.000000  1256.000000
# mean           3.431529            593.452300     6.303344  2020.371019
# std            9.705139           1085.178229     3.352281     2.046298
# min            1.000000              0.000000     1.000000  2001.000000
# 25%            1.000000            208.750000     3.000000  2020.000000
# 50%            2.000000            356.500000     6.000000  2021.000000
# 75%            3.000000            600.500000     9.000000  2022.000000
# max          220.000000          19000.000000    12.000000  2023.000000

# %%
print(existing_df_3.isnull().sum())
# Out:
# Company                   0
# Post Money Value          0
# Total Equity Funding      0
# Lead Investors Include    0
# Country                   0
# Continent                 0
# Month                     0
# Year                      0
# Industry                  0
# dtype: int64

# %% [markdown]
# ### Univariate Analysis:
#     1. Plot histograms for all numerical columns in the dataset.
#     2. For each categorical column, generate bar plots depicting the frequency of each category.

# %% [markdown]
# #### Exited Unicorn Companies

# %%
# Assuming you want to plot a count of each country in a column called 'Top Countries'
top_countries = exited_df_3['Country'].value_counts().nlargest(10).index

# Filter the dataframe to include only the top 10 countires
df_top_countries = exited_df_3[exited_df_3['Country'].isin(top_countries)]

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")  # Set the style of the plot

ax = sns.countplot(data=df_top_countries, x='Country', color="darkseagreen", order=top_countries)

plt.title('Top 10 Countries Distribution of Exited Unicorn Companies', fontsize=16, fontweight='bold')
plt.xlabel('Country', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')

plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility

# Add counts to the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', fontweight='bold', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# The majority of unicorn companies in the United States have exited, as indicated by the above chart. China comes in second.

# %%
# Assuming you want to plot a count of each industry in a column called 'Top Industries'
top_industries = exited_df_3['Main Industry'].value_counts().nlargest(10).index

# Filter the dataframe to include only the top 10 industries
df_top_industries = exited_df_3[exited_df_3['Main Industry'].isin(top_industries)]

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")  # Set the style of the plot

ax = sns.countplot(data=df_top_industries, x='Main Industry', color="darkseagreen", order=top_industries)

plt.title('Top 10 Industries Distribution of Exited Unicorn Companies', fontsize=16, fontweight='bold')
plt.xlabel('Industry', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')

plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility

# Add counts to the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', fontweight='bold', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# The majority of unicorn companies that have exited are in the software and technology industries. The Software and Technology industry accounts for 27% of all companies.

# %%
# Create a bar chart
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")  # Set the style of the plot

# Assuming you want to plot a count of each yeah in a column called 'Year'
ax = sns.countplot(data=exited_df_3, x='Year', color="darkseagreen")

plt.title('Yearly Distribution of Exited Unicorn Companies', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')

# Add counts to the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', fontweight='bold', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# According to the graph, the majority of companies were exited in 2021, with the fewest companies exiting in 2006 and 2009. From 2018 to 2020, the number of exited companies decreased, but it increased dramatically in 2021. After 2021 it has decreased yearly.

# %%
# Assuming you want to plot a count of each reason in a column called 'Exited Reasons'
exited_df_3_sorted = exited_df_3['Main Reason'].value_counts().sort_values(ascending=False).index

plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")  # Set the style of the plot

# Use the sorted order for the x-axis
ax = sns.countplot(data=exited_df_3, x='Main Reason', order=exited_df_3_sorted, color="darkseagreen")

plt.title('Main Reason to Exit the Unicorn Companies', fontsize=16, fontweight='bold')
plt.xlabel('Main Exited Reason', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')

# Add counts to the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', fontweight='bold', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# Based on the chart, the majority of the companies were shut down due to bankruptcy. The least amount of businesses have left due to devaluation.

# %% [markdown]
# #### Emerging Unicorn Companies

# %%
# Create a histogram for Post Money Value
plt.figure(figsize=(10, 6))
plt.hist(emerging_df_3['Post Money Value'], bins=7, color='lightsalmon', edgecolor='black')
plt.title('Histogram of Post Money Value', fontsize=14, fontweight='bold')
plt.xlabel('Post Fund Value (Millions USD)', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# Stating that a company named "Coro" had a valuation recorded as 0.298 Millions in our dataset. However, we believe that it is an outlier because an emerging Unicorn will always have a valuation above $500. So, we removed it for a more effective analysis

# %%
# Create a histogram for Total Equity Funding
plt.figure(figsize=(10, 6))
plt.hist(emerging_df_3['Total Equity Funding'], bins=20, color='lightsalmon', edgecolor='black')
plt.title('Histogram of Total Equity Funding', fontsize=14, fontweight='bold')
plt.xlabel('Total Equity Funding (Millions USD)', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# According to the histogram, the majority of the companies' total equity funding ranges from 0 to 200 million. There is one company that has received over 800 million total equity funding. Despite being an outlier, it is acceptable. There may be companies with a total equity fund of more than 800 million.

# %%
# Split the values in the column by commas and strip whitespaces
emerging_df_3['Lead Investors Include'] = emerging_df_3['Lead Investors Include'].str.split(',').apply(lambda x: [i.strip() for i in x])

# Create a new DataFrame to store the comma-separated data
df_split = pd.DataFrame(emerging_df_3['Lead Investors Include'].tolist(), index=emerging_df_3.index).stack().reset_index(level=1, drop=True).reset_index(name='split_values')

# Count the unique values in the column
unique_values_count = df_split['split_values'].value_counts()

# Assuming you want to plot a count of each investor in a column called 'Top Investors'
top_investors = df_split['split_values'].value_counts().nlargest(10).index

# Filter the dataframe to include only the top 10 investors
df_top_investors = df_split[df_split['split_values'].isin(top_investors)]

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")  # Set the style of the plot

ax = sns.countplot(data=df_top_investors, x='split_values', color="lightsalmon", order=top_investors)

plt.title('Top 10 Investors Distribution of Emerging Unicorn Companies', fontsize=16, fontweight='bold')
plt.xlabel('Investor', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')

plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility

# Add counts to the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', fontweight='bold', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
df_split
# Out:
#      index             split_values
# 0        0       Galaxy Interactive
# 1        0          Agnitio Capital
# 2        1                      IVP
# 3        2          M&G Investments
# 4        3  Tiger Global Management
# ..     ...                      ...
# 470    375              Lux Capital
# 471    376           Schroder Adveq
# 472    377                 Fidelity
# 473    378         General Atlantic
# 474    379        The Carlyle Group
#
# [475 rows x 2 columns]

# %% [markdown]
# According to the above bar chart, SoftBank Vision Fund invests in the majority of emerging unicorn companies. Tiger Global Management is the second largest investor in emerging unicorns.

# %%
# Assuming you want to plot a count of each country in a column called 'Top Countries'
top_countries = emerging_df_3['Country'].value_counts().nlargest(10).index

# Filter the dataframe to include only the top 10 countries
df_top_countries = emerging_df_3[emerging_df_3['Country'].isin(top_countries)]

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")  # Set the style of the plot

ax = sns.countplot(data=df_top_countries, x='Country', color="lightsalmon", order=top_countries)

plt.title('Top 10 Countries Distribution of Emerging Unicorn Companies', fontsize=16, fontweight='bold')
plt.xlabel('Country', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')

plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility

# Add counts to the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', fontweight='bold', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# According to the above bar chart, the majority of emerging unicorn companies are based in the United States. When compared to the other companies, the United States has a significant advantage.

# %%
# Sort the data by count in descending order
sorted_df = emerging_df_3['Continent'].value_counts().reset_index().rename(columns={'index': 'Continent', 'Continent': 'Count'})
sorted_df = sorted_df.sort_values(by='Count', ascending=False)

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")  # Set the style of the plot

ax = sns.barplot(data=sorted_df, x='Continent', y='Count', color="lightsalmon")

plt.title('Continent Distribution of Emerging Unicorn Companies', fontsize=16, fontweight='bold')
plt.xlabel('Continent', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')

# Add counts to the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', fontweight='bold', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# According to the above graph, the majority of emerging unicorn companies are based in North America. Asia is the second largest continent for emerging unicorns, with Oceania having the least number of emerging unicorns.

# %% [markdown]
# #### Existing Unicorn Companies

# %%
# Create a histogram for Post Money Value
plt.figure(figsize=(10, 6))
plt.hist(existing_df_3['Post Money Value'], bins=20, color='lightslategrey', edgecolor='black')
plt.title('Histogram of Post Money Value', fontsize=14, fontweight='bold')
plt.xlabel('Post Fund Value (Billions USD)', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# The histogram above shows that the post-fund value of almost all existing unicorn companies ranges from 1 billion to 50 billion. There are six unicorn companies with post-fund valuations of more than $50 billion. As a result, the histogram is skewed to the right.
#
# 1. ByteDance - $220B
#
# 2. Ant Group - $150B
#
# 3. SpaceX - $125B
#
# 4. Reliance Retail - $100B
#
# 5. Shein - $66B
#
# 6. Reliance Jio - $58B

# %%
# Create a histogram for Total Equity Funding
plt.figure(figsize=(10, 6))
plt.hist(existing_df_3['Total Equity Funding'], bins=20, color='lightslategrey', edgecolor='black')
plt.title('Histogram of Total Equity Funding', fontsize=14, fontweight='bold')
plt.xlabel('Total Equity Funding (Millions USD)', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# According to the histogram, the majority of existing companies' total equity funding ranges from 0 to 2500 million. The histogram is skewed to the right because 12 companies got more than 5000 million in total equity funding.

# %%
# Split the values in the column by commas and strip whitespaces
existing_df_3['Lead Investors Include'] = existing_df_3['Lead Investors Include'].str.split(',').apply(lambda x: [i.strip() for i in x])

# Create a new DataFrame to store the comma-separated data
df_split_existing = pd.DataFrame(existing_df_3['Lead Investors Include'].tolist(), index=existing_df_3.index).stack().reset_index(level=1, drop=True).reset_index(name='split_values')

# Count the unique values in the column
unique_values_count_existing = df_split_existing['split_values'].value_counts()

# Assuming you want to plot a count of each investor in a column called 'Top Ivestors'
top_investors_existing = df_split_existing['split_values'].value_counts().nlargest(10).index

# Filter the dataframe to include only the top 10 investors
df_top_investors_existing = df_split_existing[df_split_existing['split_values'].isin(top_investors_existing)]

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")  # Set the style of the plot

ax = sns.countplot(data=df_top_investors_existing, x='split_values', color="lightslategrey", order=top_investors_existing)

plt.title('Top 10 Investors Distribution of Existing Unicorn Companies', fontsize=16, fontweight='bold')
plt.xlabel('Investor', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')

plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility

# Add counts to the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', fontweight='bold', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# According to the bar chart, SoftBank Vision Fund is an investor in many existing unicorn companies. The second largest investor is Tiger Global Management.

# %%
# Assuming you want to plot a count of each country in a column called 'Top Countries'
top_countries = existing_df_3['Country'].value_counts().nlargest(10).index

# Filter the dataframe to include only the top 10 countries
df_top_countries = existing_df_3[existing_df_3['Country'].isin(top_countries)]

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")  # Set the style of the plot

ax = sns.countplot(data=df_top_countries, x='Country', color="lightslategrey", order=top_countries)

plt.title('Top 10 Countries Distribution of Existing Unicorn Companies', fontsize=16, fontweight='bold')
plt.xlabel('Country', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')

plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility

# Add counts to the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', fontweight='bold', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# According to the above graph, the majority of existing unicron companies originated in the United States, with China ranking second largest country.

# %%
# Sort the data by count in descending order
sorted_df = existing_df_3['Continent'].value_counts().reset_index().rename(columns={'index': 'Continent', 'Continent': 'Count'})
sorted_df = sorted_df.sort_values(by='Count', ascending=False)

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")  # Set the style of the plot

ax = sns.barplot(data=sorted_df, x='Continent', y='Count', color="lightslategrey")

plt.title('Continent Distribution of Existing Unicorn Companies', fontsize=16, fontweight='bold')
plt.xlabel('Continent', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')

# Add counts to the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', fontweight='bold', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# According to the above bar chart, the majority of existing unicorn companies are located in North America. While Africa has the least number of existing unicorns. North America and Asia are home to more than half of the existing unicorns.

# %%
# Sort the data by count in descending order
sorted_df = existing_df_3['Industry'].value_counts().reset_index().rename(columns={'index': 'Industry', 'Industry': 'Count'})
sorted_df = sorted_df.sort_values(by='Count', ascending=False)

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")  # Set the style of the plot

ax = sns.barplot(data=sorted_df, x='Industry', y='Count', color="lightslategrey")

plt.title('Industries Distribution of Existing Unicorn Companies', fontsize=16, fontweight='bold')
plt.xlabel('Industry', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')

plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility

# Add counts to the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', fontweight='bold', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# ### Bivariate Analysis:

# %% [markdown]
# #### Exited Unicorn Companies

# %%
# Assuming you want to plot a count of each industry in a column called 'Top Industries'
top_industries = exited_df_3['Main Industry'].value_counts().nlargest(10).index

# Filter the dataframe to include only the top 10 industries
df_top_industries = exited_df_3[exited_df_3['Main Industry'].isin(top_industries)]

# Create a bar chart with hue='Main Reason'
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")  # Set the style of the plot

ax = sns.countplot(data=df_top_industries, x='Main Industry', hue='Main Reason', palette='turbo_r', order=top_industries)

plt.title('Main Exit Reasons for the Top 10 Industries', fontsize=16, fontweight='bold')
plt.xlabel('Industry', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')

plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility

# Remove counts from the bars
for p in ax.patches:
    ax.annotate('', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', fontweight='bold', xytext=(0, 5),
                textcoords='offset points')

plt.legend(title='Main Reason', title_fontsize='12', loc='upper right', bbox_to_anchor=(1.15, 1))

plt.show()

# %% [markdown]
# According to the above chart, bankruptcy is the reason for the company's exit in all of the top ten industries of the exited unicorn companies. The second most important reason for an IPO. Only unicorn companies in the software and technology industries, as well as the e-commerce and retail industries, have exited due to devaluation.

# %%
# Create a stacked bar chart
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")  # Set the style of the plot

# Assuming you want to plot a count of each company in a column called 'Exit_Reason' stacked by 'Year'
ax = sns.countplot(data=exited_df_3, x='Year', hue='Main Reason', palette='turbo_r', dodge=True)

plt.title('Yearly Distribution of Exited Unicorn Companies by Exit Reason', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')

plt.legend(title='Exit Reason', title_fontsize='12', fontsize='10', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# The main reason for exiting unicorns, according to the chart from 2017 to 2023, is bankruptcy. Except for devaluation, the four main reasons to exit are higher in 2021 than in previous years. Only in 2020 will there be a devaluation.

# %% [markdown]
# #### Emerging Unicorn Companies

# %%
# Assuming 'Emerging_Companies.csv' has columns 'Lead Investors Include' and 'Country'
emerging_df_3 = pd.read_csv("Emerging_Companies.csv", encoding='unicode_escape')

# Splitting the 'InvestorColumn' and creating new rows
investor_list = emerging_df_3['Lead Investors Include'].str.split(', ')
investor_df = pd.DataFrame({
    'Investor': investor_list.sum(),  # Flatten the list of lists
    'Country': emerging_df_3['Country'].repeat(investor_list.apply(len))
})

# Counting the number of investors for each country
investor_counts = investor_df.groupby('Country').count().reset_index()

# Renaming the columns for clarity
investor_counts.columns = ['Country', 'Investor_Count']

# Display the result
print(investor_counts)
# Out:
#             Country  Investor_Count
# 0         Australia               3
# 1           Bahrain               2
# 2            Brazil               5
# 3            Canada              12
# 4             China              51
# 5          Colombia               2
# 6           Estonia               2
# 7           Finland               1
# 8            France               5
# 9           Germany              11
# 10        Hong Kong               3
# 11          Hungary               1
# 12            India              57
# 13        Indonesia               4
# 14      Isle of Man               2
# 15           Israel               7
# 16            Japan               6
# 17            Kenya               2
# 18           Kuwait               1
# 19         Malaysia               1
# 20          Nigeria               3
# 21           Norway               1
# 22           Poland               1
# 23          Romania               1
# 24        Singapore               9
# ...

# %%
# Selecting the top 10 countries
top_10_countries = investor_counts.sort_values(by='Investor_Count', ascending=False).head(10)

# Creating a bar chart with count values on top
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")
bars = plt.bar(top_10_countries['Country'], top_10_countries['Investor_Count'], color='lightsalmon')
plt.xlabel('Country', fontsize=12, fontweight='bold')
plt.ylabel('Number of Investors', fontsize=12, fontweight='bold')
plt.title('Top 10 Countries by Number of Investors in Emerging Unicorn Companies', fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Adding count values on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.1, round(yval, 1), ha='center', va='bottom', fontweight='bold')

plt.tight_layout()

# Display the bar chart
plt.show()

# %% [markdown]
# #### Existing Unicorn Companies

# %%
# Assuming 'Emerging_Companies.csv' has columns 'Lead Investors Include' and 'Country'
existing_df_3 = pd.read_csv("Unicorn_Companies.csv", encoding='unicode_escape')

# Splitting the 'InvestorColumn' and creating new rows
investor_list = existing_df_3['Lead Investors Include'].str.split(', ')
investor_df = pd.DataFrame({
    'Investor': investor_list.sum(),  # Flatten the list of lists
    'Country': existing_df_3['Country'].repeat(investor_list.apply(len))
})

# Counting the number of investors for each country
investor_counts = investor_df.groupby('Country').count().reset_index()

# Renaming the columns for clarity
investor_counts.columns = ['Country', 'Investor_Count']

# Display the result
print(investor_counts)
# Out:
#                  Country  Investor_Count
# 0              Argentina               2
# 1              Australia              19
# 2                Austria               4
# 3                Belgium               5
# 4                Bermuda               9
# 5                 Brazil              28
# 6             California               1
# 7                 Canada              38
# 8         Cayman Islands               1
# 9                  Chile               2
# 10                 China             419
# 11              Colombia               3
# 12               Croatia               2
# 13        Czech Republic               1
# 14               Denmark               3
# 15               Ecuador               1
# 16                 Egypt               1
# 17               Estonia               4
# 18               Finland               5
# 19                France              38
# 20               Germany              43
# 21                Greece               1
# ...

# %%
# Selecting the top 10 countries
top_10_countries = investor_counts.sort_values(by='Investor_Count', ascending=False).head(10)

# Creating a bar chart with count values on top
plt.figure(figsize=(12, 6))
bars = plt.bar(top_10_countries['Country'], top_10_countries['Investor_Count'], color='lightslategrey')
plt.xlabel('Country', fontsize=12, fontweight='bold')
plt.ylabel('Number of Investors', fontsize=12, fontweight='bold')
plt.title('Top 10 Countries by Number of Investors in Existing Unicorn Companies', fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Adding count values on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.1, round(yval, 1), ha='center', va='bottom', fontweight='bold')

plt.tight_layout()

# Display the bar chart
plt.show()

# %%
import pandas as pd

# Splitting the 'InvestorColumn' and creating new rows
investor_list = existing_df_3['Lead Investors Include'].str.split(', ')
investor_df = pd.DataFrame({
    'Investor': investor_list.sum(), 
    'Company': existing_df_3['Company'].repeat(investor_list.apply(len))
})

# Display the result
print(investor_df.reset_index(drop=True))
# Out:
#                           Investor           Company
# 0                           Google      Reliance Jio
# 1                              GIC         Ant Group
# 2                 Temasek Holdings         Ant Group
# 3                           Altria              JUUL
# 4                        Microsoft            OpenAI
# ...                            ...               ...
# 1984             CCB International     Wellong Etown
# 1985  China Structural Reform Fund            Xiaodu
# 1986                 Alibaba Group          Zhipu AI
# 1987                       Tencent          Zhipu AI
# 1988                 Baidu Capital  Zhiyuan Robotics
#
# [1989 rows x 2 columns]

# %%
# Counting the number of investors for each country
investor_counts = investor_df.groupby('Company').count().reset_index()

# Renaming the columns for clarity
investor_counts.columns = ['Company', 'Investor_Count']

# Display the result
print(investor_counts)
# Out:
#               Company  Investor_Count
# 0               01.AI               1
# 1          1047 Games               1
# 2               1KMXC               1
# 3            1Komma5°               1
# 4           1Password               1
# ...               ...             ...
# 1483          stc pay               1
# 1484  thatgamecompany               2
# 1485     unico IDtech               2
# 1486      v2 Ventures               1
# 1487            wefox               1
#
# [1488 rows x 2 columns]

# %%
# Assuming you have the 'investor_counts' DataFrame
investor_counts_column = investor_counts['Investor_Count']

# Get the count of each unique value
count_of_each_unique_value = investor_counts_column.value_counts()

print("Count of each unique Investor_Count value:")
print(count_of_each_unique_value)
# Out:
# Count of each unique Investor_Count value:
# 1     1070
# 2      396
# 4        6
# 3        4
# 10       3
# 5        3
# 7        2
# 6        2
# 9        1
# 11       1
# Name: Investor_Count, dtype: int64

# %%
# Assuming you have the 'investor_counts' DataFrame
investor_counts_column = investor_counts['Investor_Count']

# Get the count of each unique value
count_of_each_unique_value = investor_counts_column.value_counts()

# Increase the size of the plot
plt.figure(figsize=(15, 10))

# Plotting the bar chart
bars = plt.bar(count_of_each_unique_value.index, count_of_each_unique_value.values, color='lightslategrey')

# Adding counts on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, round(yval, 1), ha='center', va='bottom', fontweight='bold')

# Adding labels and title
plt.xlabel('Investor Count', fontsize=12, fontweight='bold')
plt.ylabel('Number of Companies', fontsize=12, fontweight='bold')
plt.title('Distribution of Investor Counts in Existing Unicorn Companies', fontsize=16, fontweight='bold')

# Adding labels to each tick on the x-axis
plt.xticks(count_of_each_unique_value.index, count_of_each_unique_value.index)

# Display the plot
plt.show()

# %% [markdown]
# Eventhough there are 1490 companies here the total count of companies is 1488, considering that there are two countries with identical names in the company list. It's important to note that these entries are not duplicates; rather, they represent two distinct companies with similar names. Despite the name similarity, they are separate entities.
#
# <img src="same.jpg" width=600 align="center">

# %% [markdown]
# ### Multivariate Analysis:

# %% [markdown]
# Connection between number of investors in a country and the number of startups

# %% [markdown]
# #### Existing Unicorn Companies

# %%
# Assuming 'Emerging_Companies.csv' has columns 'Lead Investors Include' and 'Country'
existing_df_3 = pd.read_csv("Unicorn_Companies.csv", encoding='unicode_escape')

# Splitting the 'Lead Investors Include' column and creating new rows
investor_list = existing_df_3['Lead Investors Include'].str.split(', ')
investor_df = pd.DataFrame({
    'Investor': investor_list.sum(),  # Flatten the list of lists
    'Country': existing_df_3['Country'].repeat(investor_list.apply(len))
})

# Counting the number of investors for each country
investor_counts = investor_df.groupby('Country').count().reset_index()
investor_counts.columns = ['Country', 'Investor_Count']

# Counting the number of companies for each country
company_counts = existing_df_3['Country'].value_counts().reset_index()
company_counts.columns = ['Country', 'Company_Count']

# Merging the two dataframes on the 'Country' column
result_df = pd.merge(investor_counts, company_counts, on='Country', how='outer').fillna(0)

# Display the result
print(result_df)
# Out:
#                  Country  Investor_Count  Company_Count
# 0              Argentina               2              1
# 1              Australia              19             11
# 2                Austria               4              3
# 3                Belgium               5              3
# 4                Bermuda               9              1
# 5                 Brazil              28             20
# 6             California               1              1
# 7                 Canada              38             27
# 8         Cayman Islands               1              1
# 9                  Chile               2              2
# 10                 China             419            275
# 11              Colombia               3              2
# 12               Croatia               2              1
# 13        Czech Republic               1              1
# 14               Denmark               3              3
# 15               Ecuador               1              1
# ...

# %%
df = pd.DataFrame(result_df)

# Sorting by Investor_Count for better visualization
df = df.sort_values('Investor_Count', ascending=False)

# Selecting the top 10 countries
df_top10 = df.head(10)

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

color = 'lightsalmon'
ax1.set_xlabel('Country', fontsize=12, fontweight='bold')
ax1.set_ylabel('Investor Count', color=color, fontsize=12, fontweight='bold')
ax1.plot(df_top10['Country'], df_top10['Investor_Count'], color=color, marker='o', label='Investor Count')
ax1.tick_params(axis='y', labelcolor=color)
plt.xticks(rotation=45, ha='right')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'lightslategrey'
ax2.set_ylabel('Company Count', color=color, fontsize=12, fontweight='bold')  # we already handled the x-label with ax1
ax2.bar(df_top10['Country'], df_top10['Company_Count'], color=color, label='Company Count', alpha = 0.7)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Top 10 Investor and Company Count by Country', fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# The graph above demonstrates that as the number of companies in every country declines, so does the number of investors.
